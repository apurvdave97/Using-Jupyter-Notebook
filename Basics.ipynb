# %% [markdown]
# text = open("births.csv").read()
# text

# %%
text_splitted = text.split("\n")
text_splitted
# Out:
# ['year,month,date_of_month,day_of_week,births',
#  '1994,1,1,6,8096',
#  '1994,1,2,7,7772',
#  '1994,1,3,1,10142',
#  '1994,1,4,2,11248',
#  '1994,1,5,3,11053',
#  '1994,1,6,4,11406',
#  '1994,1,7,5,11251',
#  '1994,1,8,6,8653',
#  '1994,1,9,7,7910',
#  '1994,1,10,1,10498',
#  '1994,1,11,2,11706',
#  '1994,1,12,3,11567',
#  '1994,1,13,4,11212',
#  '1994,1,14,5,11570',
#  '1994,1,15,6,8660',
#  '1994,1,16,7,8123',
#  '1994,1,17,1,10567',
#  '1994,1,18,2,11541',
#  '1994,1,19,3,11257',
#  '1994,1,20,4,11682',
#  '1994,1,21,5,11811',
#  '1994,1,22,6,8833',
#  '1994,1,23,7,8310',
#  '1994,1,24,1,11125',
#  '1994,1,25,2,11981',
#  '1994,1,26,3,11514',
#  '1994,1,27,4,11702',
#  '1994,1,28,5,11666',
#  '1994,1,29,6,8988',
#  '1994,1,30,7,8096',
#  '1994,1,31,1,10765',
#  '1994,2,1,2,11755',
#  '1994,2,2,3,11483',
#  '1994,2,3,4,11523',
#  '1994,2,4,5,11677',
#  '1994,2,5,6,8991',
#  '1994,2,6,7,8309',
#  '1994,2,7,1,10984',
#  '1994,2,8,2,12152',
#  '1994,2,9,3,11515',
# ...

# %%
3 4

# %%
a = 15
b = 35

# %%
c = a + b
c
# Out:
# 50

# %%
text = open("births.csv").read()
text_splitted = text.split("\n")

days_counts = {}
list = text_splitted[1:]
list_splitted = []
for element in list:
    element_1 = element.split(',')
    if element_1[3] in days_counts:
        days_counts[element_1[3]] += element_1[4]
    else:
        days_counts[element_1[3]] = element_1[4]
print(days_counts)
# Out:
# {'2': '...', '6': '...', '4': '...', '3': '...', '1': '...', '7': '...', '5': '...'}

# %%
text = open("births.csv").read()
text_splitted = text.split("\n")

data_no_header = text_splitted[1:len(text_splitted)]
days_counts = dict()

for line in data_no_header:
    split_line = line.split(",")
    day_of_week = split_line[3]
    num_births = int(split_line[4])

    if day_of_week in days_counts:
        days_counts[day_of_week] = days_counts[day_of_week] + num_births
    else:
        days_counts[day_of_week] = num_births

days_counts
# Out:
# {'1': 5789166,
#  '2': 6446196,
#  '3': 6322855,
#  '4': 6288429,
#  '5': 6233657,
#  '6': 4562111,
#  '7': 4079723}
